# %%
from google.colab import drive
drive.mount('/content/google_drive')
# Out:
# Mounted at /content/google_drive

# %%
# !nvidia-smi
# Out:
# Tue Nov 15 01:08:12 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  A100-SXM4-40GB      Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   29C    P0    41W / 400W |      0MiB / 40536MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install -U "tensorflow>=2.5"

# %% [markdown]
# <div><div class="highlight-default notranslate"><div class="highlight"><pre><span></span>content/
# ├─ scripts/ (Google Drive Mount)
# │  └─ preprocessing/
# ├─ models/
# │  ├─ community/
# │  ├─ official/
# │  ├─ orbit/
# │  ├─ research/
# │  └─ ...
# └─ workspace/ (Google Drive Mount)
#     └─ training_demo/
# </pre></div>

# %% [markdown]
# <div><div class="highlight-default notranslate"><div class="highlight"><pre><span></span>training_demo/
# ├─ annotations/
# ├─ exported-models/
# ├─ images/
# │  ├─ test/
# │  └─ train/
# ├─ models/
# ├─ pre-trained-models/
# └─ README.md
# </pre></div>

# %%
import os
import pathlib

import matplotlib
import matplotlib.pyplot as plt

import io
import scipy.misc
import numpy as np
from six import BytesIO
from PIL import Image, ImageDraw, ImageFont
from six.moves.urllib.request import urlopen

import tensorflow as tf
# import tensorflow_hub as hub

tf.get_logger().setLevel('ERROR')

# %%
import re
from shutil import copyfile
import argparse
import math
import random

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')   # Suppress Matplotlib warnings

# %%
# Clone the tensorflow models repository
# !git clone --depth 1 https://github.com/tensorflow/models
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 3529, done.
# remote: Counting objects: 100% (3529/3529), done.
# remote: Compressing objects: 100% (2939/2939), done.
# remote: Total 3529 (delta 928), reused 1439 (delta 536), pack-reused 0
# Receiving objects: 100% (3529/3529), 47.00 MiB | 33.85 MiB/s, done.
# Resolving deltas: 100% (928/928), done.

# %%
# !sudo apt install -y protobuf-compiler
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# protobuf-compiler is already the newest version (3.0.0-9.1ubuntu1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 5 not upgraded.

# %%
# %cd /content/models/research
# Out:
# /content/models/research

# %%
# !protoc object_detection/protos/*.proto --python_out=.

# %%
# %cd /content
# Out:
# /content

# %%
# !git clone https://github.com/cocodataset/cocoapi.git
# Out:
# Cloning into 'cocoapi'...
# remote: Enumerating objects: 975, done.
# remote: Total 975 (delta 0), reused 0 (delta 0), pack-reused 975
# Receiving objects: 100% (975/975), 11.72 MiB | 31.35 MiB/s, done.
# Resolving deltas: 100% (576/576), done.

# %%
# %cd /content/cocoapi/PythonAPI
# Out:
# /content/cocoapi/PythonAPI

# %%
# !make

# %%
# !ls -al
# Out:
# total 1780
# drwxr-xr-x 3 root root    4096 Nov 15 01:10 .
# drwxr-xr-x 8 root root    4096 Nov 15 01:10 ..
# -rw-r--r-- 1 root root     199 Nov 15 01:10 Makefile
# -rw-r--r-- 1 root root 1790308 Nov 15 01:10 pycocoDemo.ipynb
# -rw-r--r-- 1 root root    4456 Nov 15 01:10 pycocoEvalDemo.ipynb
# drwxr-xr-x 2 root root    4096 Nov 15 01:10 pycocotools
# -rw-r--r-- 1 root root     762 Nov 15 01:10 setup.py

# %%
# !cp -r pycocotools /content/models/research

# %%
# %cd /content/models/research
# Out:
# /content/models/research

# %%
# !cp object_detection/packages/tf2/setup.py .

# %%
# !python -m pip install .

# %%
# !python /content/models/research/object_detection/builders/model_builder_tf2_test.py

# %%
# !python "/content/google_drive/MyDrive/Tensorflow_OD_API/faster_rcnn_resnet50_v1/workspace/training_demo/annotations/generate_tfrecord1.py" \
-x "/content/google_drive/MyDrive/Tensorflow_OD_API/faster_rcnn_resnet50_v1/workspace/training_demo/images/test" \
-l "/content/google_drive/MyDrive/Tensorflow_OD_API/faster_rcnn_resnet50_v1/workspace/training_demo/annotations/label_map.pbtxt" \
-o "/content/google_drive/MyDrive/Tensorflow_OD_API/faster_rcnn_resnet50_v1/workspace/training_demo/annotations/test.record"

# %% [markdown]
# /content/google_drive/MyDrive/Tensorflow_OD_API/faster_rcnn_resnet50_v1/workspace/training_demo/exported-models/

# %%
# !mkdir "/content/google_drive/MyDrive/Tensorflow_OD_API/faster_rcnn_resnet50_v1/workspace/training_demo/models/myft_faster_rcnn_resnet50_v2"

# %%
# !cp "/content/google_drive/MyDrive/Tensorflow_OD_API/faster_rcnn_resnet50_v1/workspace/training_demo/models/myft_faster_rcnn_resnet50_v1/pipeline.config" \
"/content/google_drive/MyDrive/Tensorflow_OD_API/faster_rcnn_resnet50_v1/workspace/training_demo/models/myft_faster_rcnn_resnet50_v2"

# %%
# !python /content/models/research/object_detection/model_main_tf2.py \
--model_dir="/content/google_drive/MyDrive/Tensorflow_OD_API/faster_rcnn_resnet50_v1/workspace/training_demo/models/myft_faster_rcnn_resnet50_v2" \
--pipeline_config_path="/content/google_drive/MyDrive/Tensorflow_OD_API/faster_rcnn_resnet50_v1/workspace/training_demo/models/myft_faster_rcnn_resnet50_v2/pipeline.config" \
--alsologtostderr

# %% [markdown]
# Keyboard : standardinput \
# monitor  : standardoutput \
# error    : standarderror

# %%
# mAP check
# !python /content/models/research/object_detection/model_main_tf2.py \
--model_dir="/content/google_drive/MyDrive/Tensorflow_OD_API/faster_rcnn_resnet50_v1/workspace/training_demo/models/myft_faster_rcnn_resnet50_v2" \
--pipeline_config_path="/content/google_drive/MyDrive/Tensorflow_OD_API/faster_rcnn_resnet50_v1/workspace/training_demo/models/myft_faster_rcnn_resnet50_v2/pipeline.config" \
--checkpoint_dir="/content/google_drive/MyDrive/Tensorflow_OD_API/faster_rcnn_resnet50_v1/workspace/training_demo/models/myft_faster_rcnn_resnet50_v2"

# %%
# re-training mAP
#
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.333
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.527
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.368
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.055
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.160
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.422
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.368
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.535
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.567
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.235
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.420
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.665
# INFO:tensorflow:Eval metrics at step 5000
# I1115 01:32:55.157197 140217613088640 model_lib_v2.py:1015] Eval metrics at step 5000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP: 0.333002
# I1115 01:32:55.229983 140217613088640 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP: 0.333002 <<<<<<
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.50IOU: 0.527028
# I1115 01:32:55.231633 140217613088640 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.50IOU: 0.527028
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.75IOU: 0.368068
# I1115 01:32:55.233016 140217613088640 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.75IOU: 0.368068
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (small): 0.054979
# I1115 01:32:55.234316 140217613088640 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (small): 0.054979
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (medium): 0.160012
# I1115 01:32:55.235606 140217613088640 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (medium): 0.160012
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (large): 0.422124
# I1115 01:32:55.236864 140217613088640 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (large): 0.422124
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@1: 0.368083
# I1115 01:32:55.238129 140217613088640 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@1: 0.368083
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@10: 0.535005
# I1115 01:32:55.239379 140217613088640 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@10: 0.535005
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100: 0.566709
# I1115 01:32:55.240649 140217613088640 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100: 0.566709
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (small): 0.235433
# I1115 01:32:55.241887 140217613088640 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (small): 0.235433
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (medium): 0.419977
# I1115 01:32:55.243148 140217613088640 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (medium): 0.419977
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (large): 0.664583
# I1115 01:32:55.244539 140217613088640 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (large): 0.664583
# INFO:tensorflow:	+ Loss/RPNLoss/localization_loss: 0.206257
# I1115 01:32:55.245524 140217613088640 model_lib_v2.py:1018] 	+ Loss/RPNLoss/localization_loss: 0.206257
# INFO:tensorflow:	+ Loss/RPNLoss/objectness_loss: 0.157498
# I1115 01:32:55.246527 140217613088640 model_lib_v2.py:1018] 	+ Loss/RPNLoss/objectness_loss: 0.157498
# INFO:tensorflow:	+ Loss/BoxClassifierLoss/localization_loss: 0.155243
# I1115 01:32:55.247517 140217613088640 model_lib_v2.py:1018] 	+ Loss/BoxClassifierLoss/localization_loss: 0.155243
# INFO:tensorflow:	+ Loss/BoxClassifierLoss/classification_loss: 0.219280
# I1115 01:32:55.248502 140217613088640 model_lib_v2.py:1018] 	+ Loss/BoxClassifierLoss/classification_loss: 0.219280
# INFO:tensorflow:	+ Loss/regularization_loss: 0.000000
# I1115 01:32:55.249481 140217613088640 model_lib_v2.py:1018] 	+ Loss/regularization_loss: 0.000000
# INFO:tensorflow:	+ Loss/total_loss: 0.738278
# I1115 01:32:55.250454 140217613088640 model_lib_v2.py:1018] 	+ Loss/total_loss: 0.738278 <<<<<<
# INFO:tensorflow:Exiting evaluation at step 5000
# I1115 01:32:55.571327 140217613088640 model_lib_v2.py:1168] Exiting evaluation at step 5000

# %%
# 모델 세이브 후 2번째 re-train

# %%
# %cd /content/google_drive/MyDrive/Tensorflow_OD_API/faster_rcnn_resnet50_v1/workspace/training_demo/models
# Out:
# /content/google_drive/MyDrive/Tensorflow_OD_API/faster_rcnn_resnet50_v1/workspace/training_demo/models

# %%
# !mkdir myft_faster_rcnn_resnet50_v3

# %%
# !cp "/content/google_drive/MyDrive/Tensorflow_OD_API/faster_rcnn_resnet50_v1/workspace/training_demo/models/myft_faster_rcnn_resnet50_v2/pipeline.config" \
/content/google_drive/MyDrive/Tensorflow_OD_API/faster_rcnn_resnet50_v1/workspace/training_demo/models/myft_faster_rcnn_resnet50_v3

# %%
 # !python /content/models/research/object_detection/model_main_tf2.py \
--model_dir="/content/google_drive/MyDrive/Tensorflow_OD_API/faster_rcnn_resnet50_v1/workspace/training_demo/models/myft_faster_rcnn_resnet50_v3" \
--pipeline_config_path="/content/google_drive/MyDrive/Tensorflow_OD_API/faster_rcnn_resnet50_v1/workspace/training_demo/models/myft_faster_rcnn_resnet50_v3/pipeline.config" \
--alsologtostderr
# Out:
# 2022-11-15 02:26:16.989752: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-11-15 02:26:17.780999: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-11-15 02:26:17.781100: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# ...

# %%
# mAP check 2
# !python /content/models/research/object_detection/model_main_tf2.py \
--model_dir="/content/google_drive/MyDrive/Tensorflow_OD_API/faster_rcnn_resnet50_v1/workspace/training_demo/models/myft_faster_rcnn_resnet50_v3" \
--pipeline_config_path="/content/google_drive/MyDrive/Tensorflow_OD_API/faster_rcnn_resnet50_v1/workspace/training_demo/models/myft_faster_rcnn_resnet50_v3/pipeline.config" \
--checkpoint_dir="/content/google_drive/MyDrive/Tensorflow_OD_API/faster_rcnn_resnet50_v1/workspace/training_demo/models/myft_faster_rcnn_resnet50_v3"
# Out:
# 2022-11-15 02:41:50.126412: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-11-15 02:41:50.919783: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-11-15 02:41:50.919883: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# ...

# %%
# re-trained mAP 2
# 
# I1115 02:44:57.778623 140093962700672 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP: 0.349653
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.50IOU: 0.550200
# I1115 02:44:57.780262 140093962700672 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.50IOU: 0.550200
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.75IOU: 0.378409
# I1115 02:44:57.781746 140093962700672 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.75IOU: 0.378409
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (small): 0.068408
# I1115 02:44:57.783106 140093962700672 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (small): 0.068408
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (medium): 0.173313
# I1115 02:44:57.784478 140093962700672 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (medium): 0.173313
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (large): 0.444069
# I1115 02:44:57.785837 140093962700672 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (large): 0.444069
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@1: 0.383422
# I1115 02:44:57.787214 140093962700672 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@1: 0.383422
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@10: 0.546525
# I1115 02:44:57.788569 140093962700672 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@10: 0.546525
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100: 0.575514
# I1115 02:44:57.789907 140093962700672 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100: 0.575514
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (small): 0.244868
# I1115 02:44:57.791256 140093962700672 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (small): 0.244868
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (medium): 0.403348
# I1115 02:44:57.792614 140093962700672 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (medium): 0.403348
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (large): 0.679106
# I1115 02:44:57.794084 140093962700672 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (large): 0.679106
# INFO:tensorflow:	+ Loss/RPNLoss/localization_loss: 0.198517
# I1115 02:44:57.795094 140093962700672 model_lib_v2.py:1018] 	+ Loss/RPNLoss/localization_loss: 0.198517
# INFO:tensorflow:	+ Loss/RPNLoss/objectness_loss: 0.151228
# I1115 02:44:57.796137 140093962700672 model_lib_v2.py:1018] 	+ Loss/RPNLoss/objectness_loss: 0.151228
# INFO:tensorflow:	+ Loss/BoxClassifierLoss/localization_loss: 0.154739
# I1115 02:44:57.797172 140093962700672 model_lib_v2.py:1018] 	+ Loss/BoxClassifierLoss/localization_loss: 0.154739
# INFO:tensorflow:	+ Loss/BoxClassifierLoss/classification_loss: 0.214673
# I1115 02:44:57.798199 140093962700672 model_lib_v2.py:1018] 	+ Loss/BoxClassifierLoss/classification_loss: 0.214673
# INFO:tensorflow:	+ Loss/regularization_loss: 0.000000
# I1115 02:44:57.799225 140093962700672 model_lib_v2.py:1018] 	+ Loss/regularization_loss: 0.000000
# INFO:tensorflow:	+ Loss/total_loss: 0.719158
# I1115 02:44:57.800252 140093962700672 model_lib_v2.py:1018] 	+ Loss/total_loss: 0.719158
# INFO:tensorflow:Exiting evaluation at step 5000
# I1115 02:44:58.113150 140093962700672 model_lib_v2.py:1168] Exiting evaluation at step 5000

# %% [markdown]
# * summary
#
# | train | mAP | total loss | BoxClassifierLoss/localization_loss | BoxClassifierLoss/classification_loss |
# | :-----: | :---: | :----: | :----: | :-----: |
# |   1   | DetectionBoxes_Precision/mAP: 0.299957 | 0.749267 | 0.156556 | 0.222181|
# |   2   |   0.333002   |  0.738278 | 0.155243 | 0.219280   |
# |   3   |   0.349653   |  0.719158 | 0.154739 | 0.214673   |
#
#
# 배치사이즈 4 스텝 5000 <br>
# 3번 트레이닝 <br>
# 컴퓨팅 단위 100 -> 39 <br>

# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir="/content/google_drive/MyDrive/Tensorflow_OD_API/faster_rcnn_resnet50_v1/workspace/training_demo/models/myft_faster_rcnn_resnet50_v3"
